# %%
a=1
b=2
print(a+b)
# Out:
# 3

# %%
import matplotlib
x=[1,2,3,4,5]
y=[2,3,4,5,6]
print(x,y)
# Out:
# [1, 2, 3, 4, 5] [2, 3, 4, 5, 6]

# %%
from matplotlib import pyplot as plt
fig1 = plt.figure(figsize=(5,5))
plt.plot(x,y)
plt.title("y vs x")
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
print("hello")
# Out:
# hello
